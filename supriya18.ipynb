# %%
#1. What advantages do Excel spreadsheets have over CSV spreadsheets?

"""Excel:- Microsoft excel is used to display the data in horizontal and vertical rows.
           The data are ususally stored in the cells. We have an option of formulas
           in Excel that can be used for data and its palce of storage. You can
           even add any charts, ghraphics, etc. to make it more presentable.
           
   CSV:-   CSV refers to Comma-Seprated Values. It holds plain text as a series of
           value(cella) seprated by commas(,) in a series of line(rows). CVS
           file can actually open in a text editor and raed it. There are
           lots of apllications for reading CVS files, and many language provide
           built-in fuctions that simplify reading/writing CVS foramt. These
           file are majority used by professional in data analysis or visualization."""

#2.What do you pass to csv.reader() and csv.writer() to create reader and writer objects?

"""csv.(reader):-  Return a reader object which will iterate over line is the given csvfile. csvfile can
                   be any object which support the iterator protocol and returns a string each time
                   its__next__() method is called-file objects and list objects are both suitable.
                   If csvfile is a file objects, it should be opened with newline=''. 
                    csv.reader(csvfile, dialect= 'execl', **fmtparams).
   
   csv.(writer):- Return a writer object responsible for converting the user's data into delimited 
                  string on the given file-like object. csvfile can be any object with a writer()
                  method. If csvfile object, it should be opened with newline=''. An optional
                  dialect parameter can be given which is used to define a set of parameter specific
                  to a particular CSV dialect.
                  csv.writer(csvfile. dialect= 'excel', **fmtparams)."""

#3. What modes do File objects for reader and writer objects need to be opened in?

"""In order to open a file for reader and writer purpose, we must use the built-in
   open() fuction.
   The open() fuction uses two arguments. File is the name of the file and second
   is for we want to open it .i.e. for reader and writer. 
   The syntax to open file object is:
        File_obj = ("file", "mode")."""

#4. What method takes a list argument and writes it to a CSV file?

"""CSV file a type of a plain text document in which tabluar information is structure 
   using a paricular format. A CSV file is a bouneded text format which uses a comma to
   seprate values. The most comma method to write data from a list to CSV file is the
   writerow() method of writer and DirectWriter class."""

#5. What do the keyword arguments delimiter and line terminator do?

"""This change the delimeter and line terminator character in your file. The delimeter 
   is the character that appears between cells on a rows. By default, the delimeter
   for a CSV file is a comma. The line terminator is the character that comes at the
   end of a row. By default, the line terminator is a newline."""

#6. What function takes a string of JSON data and returns a Python data structure?

"""JSON is JavaScript Object Notation. It means that scripts(executeable) file 
   which is made of text in programming language, is used to store and transfer 
   the data. Python supports JSON through a built- in package called JSON.
   To use this feature, we import the JSON package in Python script. The 
   text in JSON is done through quoted-string which contains the value in key- 
   value mapping within{}. It is similar to the dictonary in Python JSON shows 
   an API similar to users of Standard Library marshal and pickle modules and Python
   natively supprots JSON feature."""

#7. What function takes a Python data structure and returns a string of JSON data?

"""The full form of JSON is JavaScript Object Notation. Its means that a cript (executeable)
   file which is made of text in a programming language, is used to stroe and transfer the data.
   Python suppots JSON through a built - in package called JSONand this module can be used to 
   convert a python dictionary is used to get its equivalent JSON object."""
